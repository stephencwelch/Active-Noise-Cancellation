# %% [markdown]
# #LMS Demo [Ver 0]
#
# Sajil C K and Stephen Welch
#
# June 1, 2015

# %% [markdown]
# ##Plotting an arbitrary sin wave:

# %% [markdown]
# Import Modules:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.io.wavfile import write
from IPython.html.widgets import *
from IPython.display import Audio
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# Parameter Specifications:

# %%
Fs  = 44100  # Set Sampling Rate here
f   = 1000   # Set starting frequency here
T   = 1      # Set duration of wave to be generated here

# %% [markdown]
# Generate Time Vector:

# %%
t= np.arange(0, T, (1.0/Fs) )

# %% [markdown]
# Generate Output Vector:

# %%
x = np.sin(2 * np.pi * f * t)

# %% [markdown]
# And plot!

# %%
rangeToPlot = np.arange(0, Fs/100)

plt.plot(t[rangeToPlot], x[rangeToPlot])
plt.title('Generated Wave')
plt.xlabel('Time(in sec)')
plt.ylabel('Voltage(V)')

plt.grid(1)

# %% [markdown]
# Write to wav and play:

# %%
#Normalize + Export:
xNorm = x/max(abs(x))
write('sinWave' + '.wav', Fs,x)

# %% [markdown]
# And play in notebook:

# %%
Audio(x,rate=Fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##Controlling frequency with a slider:

# %%
def generateSineWave(frequency,phi):
    
    Fs  = 44100  # Set Sampling Rate here
    T   = 1     # Set duration of wave to be generated here
    t= np.arange(0, T, (1.0/Fs) )
    
    x = np.sin(2 * np.pi * frequency * t+phi)
    
    rangeToPlot = np.arange(0, Fs/100)
    plt.plot(t[rangeToPlot], x[rangeToPlot])
    
    plt.title('Generated Wave')
    plt.xlabel('Time(in sec)')
    plt.ylabel('Voltage(V)')
    
    plt.grid(1)
    
    return Audio(x,rate=Fs)

# %%
generateSineWave(5000,0)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.html.widgets import*

# %%
interact(generateSineWave, frequency = (100, 15000),phi = (0, 180))
